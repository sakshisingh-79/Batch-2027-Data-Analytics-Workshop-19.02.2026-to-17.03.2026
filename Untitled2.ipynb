# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshisingh-79/Batch-2027-Data-Analytics-Workshop-19.02.2026-to-17.03.2026/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''import pandas as pd
lst = ['Greek', 'For','Greek','is','portal','for','Greek']
df=pd.DataFrame(lst)
print(df)

import pandas as pd
data = {'Name':['Tom','nick','krish','jack'],
        'Age':[20,21,19,18]}
df = pd.DataFrame(data)
print(df)

#1
import pandas as pd
numbers = [10, 20, 30, 40, 50, 20]
data = pd.Series(numbers)
print("Mean:", data.mean())
print("Median:", data.median())
print("Mode:", data.mode()[0])
print("Variance:", data.var())
print("Standard Deviation:", data.std())

#2numpy array operations
import numpy as np
import pandas as pd
arr = np.array([10, 20, 30, 40, 50])
data = pd.Series(arr)
print("Sum:", data.sum())
print("Mean:", data.mean())
print("Maximum:", data.max())
print("Minumum:", data.min())
reshaped = arr.reshape(5, 1)
print("Reshaped Array:\n", reshaped)
result = arr * 2
print("Element-wise Multiplication:\n", result)

#3Matrix Operations
import pandas as pd
import numpy as np
A = pd.DataFrame([[1,2],[3,4]])
B = pd.DataFrame([[5,6],[7,8]])
print("Addition:\n", A + B)
print("Subtraction:\n", A - B)

print("Matrix Multiplication:\n", A.dot(B))
print("Transpose of A:\n", A.T)

#4Random Array of 10 numbers
import pandas as pd
import numpy as np
random_numbers = np.random.randint(1, 100, 10)
data = pd.Series(random_numbers)

print("Random Numbers:", random_numbers)
print("Mean:", data.mean())
print("Standard Deviation:", data.std())
print("Maximum:", data.max())
print("Minimum:", data.min())

#5using scipy (mean and T-test)
import pandas as pd
from scipy import stats
data = pd.Series([10, 12, 15, 18, 20])
mean_value = stats.tmean(data)
print("Mean:", mean_value)
t_stats, p_value = stats.ttest_1samp(data, 15)
print("T-statistic:", t_stats)
print("P-value:", p_value)

#6Definite integration
from scipy import integrate
def f(x):
  return x**2
result, error = integrate.quad(f, 0, 3)
print("Definite Integration Result:", result)'''

#7Minimize Function
from scipy.optimize import minimize
def f(x):
  return x**2 + 4*x + 4
result = minimize(f, x0=0)
print("Minimum Value:", result.fun)
# Out:
# Minimum Value: 0.0
